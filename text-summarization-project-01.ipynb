# %% [markdown]
# ### Reference
#
# - [Extractive Text Summarization Using spaCy in Python](https://medium.com/better-programming/extractive-text-summarization-using-spacy-in-python-88ab96d1fd97)

# %% [markdown]
# # TF-IDF
#
# - TF-IDF *(Term Frequency-Inverse Data Frequency)* is used to calculate the importance of a sentence for text summarization in
#
#     - *information retrieval* and
#
#     - *text mining*
#
#
# ## TF: Term Frequency
#
# - measure of frequency of a term in a document
#
# *normalization*
#
# - since every document is different in length, it is possible that a term would appear many more times in long documents than shorter ones
#
# - thus, *the term frequency is often divided by the document length* (such as the total number of terms in the document) as a way of normalization
#
#
#
# ## IDF: Inverse Document Frequency
#
# - measures how important a term is
#
# *stopwords*
#
# - while computing the term frequency (TF), all terms are considered equally important
#
# - however, it is known that certain terms may appear a lot of times but have little importance in the document
#     - For example: is, are, they, and so on
#     - these are called stopwords

# %% [markdown]
# ### TF-IDF Limitations
#
# - A common term in a domain might be an important term in another domain
#
#     - As the saying goes: “One man’s meat is another man’s poison”
#
# - TF-IDF is not a good choice if you are dealing with multiple domains
#
#     -  A unbalanced dataset tends to be biased and it will greatly affect the result

# %% [markdown]
# # Identifying top sentences in an article (Text Summarization)

# %% [markdown]
# Following are the steps in text summarization:
#
# 1. tokenize article using spacy's language model
#
# 2. extract important keywords and normalize weight
#
# 3. calculate importance of each sentence in the article based on keyword appearance
#
# 4. sort the sentence based on the calculated importance

# %% [markdown]
# ## Implementation

# %%
# conduct imports
import spacy 
from collections import Counter
from string import punctuation
import pprint

# %% [markdown]
# ### Load SpaCy Model

# %%
# load large english web model
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ### Text to summarize

# %%
# input_text = '''Yamaha is reminding people that musical equipment cases are for musical equipment — not people — two weeks after fugitive auto titan Carlos Ghosn reportedly was smuggled out of Japan in one. In a tweet over the weekend, the Japanese musical equipment company said it was not naming any names, but noted there had been many recent stories about people getting into musical equipment cases. Yamaha (YAMCY) warned people not to get into, or let others get into, its cases to avoid "unfortunate accidents." Multiple media outlets have reported that Ghosn managed to sneak through a Japanese airport to a private jet that whisked him out of the country by hiding in a large, black music equipment case with breathing holes drilled in the bottom. CNN Business has not independently confirmed those details of his escape. The former Nissan (NSANF) CEO had been out on bail awaiting trial in Japan on charges of financial wrongdoing before making his stunning escape to Lebanon at the end of December. Ghosn has referred to his departure as an effort to "escape injustice." In an interview with CNN\'s Richard Quest last week, Ghosn did not comment on the nature of his escape, saying he didn\'t want to endanger any of the people who aided in the operation. Ghosn did, however, respond to a question about what it felt like to ride through the airport in a packing case by first declining to comment but then adding: "Freedom, no matter the way it happens, is always sweet." In a press conference in Lebanon ahead of the CNN interview last Wednesday, Ghosn\'s first public appearance since fleeing Japan, Ghosn said he decided to leave the country because he believed he would not receive a fair trial, a claim Japanese authorities have disputed. Brands sometimes capitalize on their tangential relationship to big news in order to attract attention on social media. Yamaha is one of Japan\'s best known brands and Ghosn was one of Japan\'s top executives before being ousted from Nissan — a match made in social media heaven. Not surprisingly, Yamaha\'s post went viral on Twitter over the weekend.'''

# %%
input_text = '''Vice President Mike Pence was administered the Covid-19 vaccine in a televised event Friday, becoming the senior-most member of the Trump administration known to have received the shot.

Mr. Pence said he hoped his vaccination would help to build public confidence that the vaccine was safe and effective. It isn’t known whether President Trump and first lady Melania Trump, who both contracted Covid-19 this fall, will receive the vaccine in the coming weeks. White House press secretary Kayleigh McEnany said this week that the president is open to taking the vaccine but “wants to show Americans that our priority are the most vulnerable.”

President-elect Joe Biden and his wife, Jill Biden, will get the vaccine in public on Monday, his transition team said.

The transition team said Vice President-elect Kamala Harris and her husband, Doug Emhoff, would receive the vaccine the following week.

Mr. Pence received his first of two doses alongside second lady Karen Pence and Surgeon General Jerome Adams, in an event held in the Eisenhower Executive Office Building, in front of two signs reading “Safe and Effective.” Dr. Adams flashed the vice president a thumbs-up after all three of them had received their shots.'''

# %% [markdown]
# ### Tokenize text

# %%
doc = nlp(input_text.lower())

# %% [markdown]
# ### Explore the tokens

# %%
print("token ----- lemma_ ----- is_stop? ----- part-of-speech")
print('='*75)
for token in doc:
    print(f" {str(token)} ----- {str(token.lemma_)} ----- {str(token.is_stop)} ----- {str(token.pos_)}")
# Out:
# token ----- lemma_ ----- is_stop? ----- part-of-speech
# ===========================================================================
#  vice ----- vice ----- False ----- PROPN
#  president ----- president ----- False ----- PROPN
#  mike ----- mike ----- False ----- PROPN
#  pence ----- pence ----- False ----- PROPN
#  was ----- be ----- True ----- AUX
#  administered ----- administer ----- False ----- VERB
#  the ----- the ----- True ----- DET
#  covid-19 ----- covid-19 ----- False ----- NUM
#  vaccine ----- vaccine ----- False ----- NOUN
#  in ----- in ----- True ----- ADP
#  a ----- a ----- True ----- DET
#  televised ----- televise ----- False ----- VERB
#  event ----- event ----- False ----- NOUN
#  friday ----- friday ----- False ----- PROPN
#  , ----- , ----- False ----- PUNCT
#  becoming ----- become ----- True ----- VERB
#  the ----- the ----- True ----- DET
#  senior ----- senior ----- False ----- ADV
#  - ----- - ----- False ----- PUNCT
#  most ----- most ----- True ----- ADJ
#  member ----- member ----- False ----- NOUN
#  of ----- of ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  trump ----- trump ----- False ----- PROPN
#  administration ----- administration ----- False ----- NOUN
#  known ----- know ----- False ----- VERB
#  to ----- to ----- True ----- PART
#  have ----- have ----- True ----- AUX
#  received ----- receive ----- False ----- VERB
#  the ----- the ----- True ----- DET
#  shot ----- shot ----- False ----- NOUN
#  . ----- . ----- False ----- PUNCT
#
#
#  -----
#
#  ----- False ----- SPACE
#  mr ----- mr ----- False ----- PROPN
#  . ----- . ----- False ----- PROPN
#  pence ----- pence ----- False ----- PROPN
#  said ----- say ----- False ----- VERB
#  he ----- -PRON- ----- True ----- PRON
#  hoped ----- hope ----- False ----- VERB
#  his ----- -PRON- ----- True ----- DET
#  vaccination ----- vaccination ----- False ----- NOUN
#  would ----- would ----- True ----- VERB
#  help ----- help ----- False ----- VERB
#  to ----- to ----- True ----- PART
#  build ----- build ----- False ----- VERB
#  public ----- public ----- False ----- ADJ
#  confidence ----- confidence ----- False ----- NOUN
#  that ----- that ----- True ----- SCONJ
#  the ----- the ----- True ----- DET
#  vaccine ----- vaccine ----- False ----- NOUN
#  was ----- be ----- True ----- AUX
#  safe ----- safe ----- False ----- ADJ
#  and ----- and ----- True ----- CCONJ
#  effective ----- effective ----- False ----- ADJ
#  . ----- . ----- False ----- PUNCT
#  it ----- -PRON- ----- True ----- PRON
#  is ----- be ----- True ----- AUX
#  n’t ----- not ----- True ----- PART
#  known ----- know ----- False ----- VERB
#  whether ----- whether ----- True ----- SCONJ
#  president ----- president ----- False ----- PROPN
#  trump ----- trump ----- False ----- PROPN
#  and ----- and ----- True ----- CCONJ
#  first ----- first ----- True ----- ADJ
#  lady ----- lady ----- False ----- PROPN
#  melania ----- melania ----- False ----- PROPN
#  trump ----- trump ----- False ----- PROPN
#  , ----- , ----- False ----- PUNCT
#  who ----- who ----- True ----- PRON
#  both ----- both ----- True ----- DET
#  contracted ----- contract ----- False ----- VERB
#  covid-19 ----- covid-19 ----- False ----- NOUN
#  this ----- this ----- True ----- DET
#  fall ----- fall ----- False ----- NOUN
#  , ----- , ----- False ----- PUNCT
#  will ----- will ----- True ----- VERB
#  receive ----- receive ----- False ----- VERB
#  the ----- the ----- True ----- DET
#  vaccine ----- vaccine ----- False ----- NOUN
#  in ----- in ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  coming ----- come ----- False ----- VERB
#  weeks ----- week ----- False ----- NOUN
#  . ----- . ----- False ----- PUNCT
#  white ----- white ----- False ----- PROPN
#  house ----- house ----- False ----- PROPN
#  press ----- press ----- False ----- PROPN
#  secretary ----- secretary ----- False ----- PROPN
#  kayleigh ----- kayleigh ----- False ----- PROPN
#  mcenany ----- mcenany ----- False ----- PROPN
#  said ----- say ----- False ----- VERB
#  this ----- this ----- True ----- DET
#  week ----- week ----- False ----- NOUN
#  that ----- that ----- True ----- SCONJ
#  the ----- the ----- True ----- DET
#  president ----- president ----- False ----- NOUN
#  is ----- be ----- True ----- AUX
#  open ----- open ----- False ----- ADJ
#  to ----- to ----- True ----- ADP
#  taking ----- take ----- False ----- VERB
#  the ----- the ----- True ----- DET
#  vaccine ----- vaccine ----- False ----- NOUN
#  but ----- but ----- True ----- CCONJ
#  “ ----- " ----- False ----- PUNCT
#  wants ----- want ----- False ----- VERB
#  to ----- to ----- True ----- PART
#  show ----- show ----- True ----- VERB
#  americans ----- americans ----- False ----- PROPN
#  that ----- that ----- True ----- SCONJ
#  our ----- -PRON- ----- True ----- DET
#  priority ----- priority ----- False ----- NOUN
#  are ----- be ----- True ----- AUX
#  the ----- the ----- True ----- DET
#  most ----- most ----- True ----- ADV
#  vulnerable ----- vulnerable ----- False ----- ADJ
#  . ----- . ----- False ----- PUNCT
#  ” ----- " ----- False ----- PUNCT
#
#
#  -----
#
#  ----- False ----- SPACE
#  president ----- president ----- False ----- PROPN
#  - ----- - ----- False ----- PUNCT
#  elect ----- elect ----- False ----- PROPN
#  joe ----- joe ----- False ----- PROPN
#  biden ----- biden ----- False ----- PROPN
#  and ----- and ----- True ----- CCONJ
#  his ----- -PRON- ----- True ----- DET
#  wife ----- wife ----- False ----- NOUN
#  , ----- , ----- False ----- PUNCT
#  jill ----- jill ----- False ----- PROPN
#  biden ----- biden ----- False ----- PROPN
#  , ----- , ----- False ----- PUNCT
#  will ----- will ----- True ----- VERB
#  get ----- get ----- True ----- AUX
#  the ----- the ----- True ----- DET
#  vaccine ----- vaccine ----- False ----- NOUN
#  in ----- in ----- True ----- ADP
#  public ----- public ----- False ----- NOUN
#  on ----- on ----- True ----- ADP
#  monday ----- monday ----- False ----- PROPN
#  , ----- , ----- False ----- PUNCT
#  his ----- -PRON- ----- True ----- DET
#  transition ----- transition ----- False ----- NOUN
#  team ----- team ----- False ----- NOUN
#  said ----- say ----- False ----- VERB
#  . ----- . ----- False ----- PUNCT
#
#
#  -----
#
#  ----- False ----- SPACE
#  the ----- the ----- True ----- DET
#  transition ----- transition ----- False ----- NOUN
#  team ----- team ----- False ----- NOUN
#  said ----- say ----- False ----- VERB
#  vice ----- vice ----- False ----- NOUN
#  president ----- president ----- False ----- PROPN
#  - ----- - ----- False ----- PUNCT
#  elect ----- elect ----- False ----- PROPN
#  kamala ----- kamala ----- False ----- PROPN
#  harris ----- harris ----- False ----- PROPN
#  and ----- and ----- True ----- CCONJ
#  her ----- -PRON- ----- True ----- DET
#  husband ----- husband ----- False ----- NOUN
#  , ----- , ----- False ----- PUNCT
#  doug ----- doug ----- False ----- PROPN
#  emhoff ----- emhoff ----- False ----- PROPN
#  , ----- , ----- False ----- PUNCT
#  would ----- would ----- True ----- VERB
#  receive ----- receive ----- False ----- VERB
#  the ----- the ----- True ----- DET
#  vaccine ----- vaccine ----- False ----- NOUN
#  the ----- the ----- True ----- DET
#  following ----- following ----- False ----- ADJ
#  week ----- week ----- False ----- NOUN
#  . ----- . ----- False ----- PUNCT
#
#
#  -----
#
#  ----- False ----- SPACE
#  mr ----- mr ----- False ----- PROPN
#  . ----- . ----- False ----- PROPN
#  pence ----- pence ----- False ----- PROPN
#  received ----- receive ----- False ----- VERB
#  his ----- -PRON- ----- True ----- DET
#  first ----- first ----- True ----- ADJ
#  of ----- of ----- True ----- ADP
#  two ----- two ----- True ----- NUM
#  doses ----- dose ----- False ----- NOUN
#  alongside ----- alongside ----- False ----- ADP
#  second ----- second ----- False ----- ADJ
#  lady ----- lady ----- False ----- PROPN
#  karen ----- karen ----- False ----- PROPN
#  pence ----- pence ----- False ----- PROPN
#  and ----- and ----- True ----- CCONJ
#  surgeon ----- surgeon ----- False ----- PROPN
#  general ----- general ----- False ----- PROPN
#  jerome ----- jerome ----- False ----- PROPN
#  adams ----- adams ----- False ----- PROPN
#  , ----- , ----- False ----- PUNCT
#  in ----- in ----- True ----- ADP
#  an ----- an ----- True ----- DET
#  event ----- event ----- False ----- NOUN
#  held ----- hold ----- False ----- VERB
#  in ----- in ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  eisenhower ----- eisenhower ----- False ----- PROPN
#  executive ----- executive ----- False ----- ADJ
#  office ----- office ----- False ----- NOUN
#  building ----- building ----- False ----- NOUN
#  , ----- , ----- False ----- PUNCT
#  in ----- in ----- True ----- ADP
#  front ----- front ----- True ----- NOUN
#  of ----- of ----- True ----- ADP
#  two ----- two ----- True ----- NUM
#  signs ----- sign ----- False ----- NOUN
#  reading ----- read ----- False ----- VERB
#  “ ----- " ----- False ----- PUNCT
#  safe ----- safe ----- False ----- ADJ
#  and ----- and ----- True ----- CCONJ
#  effective ----- effective ----- False ----- ADJ
#  . ----- . ----- False ----- PUNCT
#  ” ----- " ----- False ----- PUNCT
#  dr ----- dr ----- False ----- PROPN
#  . ----- . ----- False ----- PROPN
#  adams ----- adams ----- False ----- PROPN
#  flashed ----- flash ----- False ----- VERB
#  the ----- the ----- True ----- DET
#  vice ----- vice ----- False ----- NOUN
#  president ----- president ----- False ----- NOUN
#  a ----- a ----- True ----- DET
#  thumbs ----- thumbs ----- False ----- NOUN
#  - ----- - ----- False ----- PUNCT
#  up ----- up ----- True ----- NOUN
#  after ----- after ----- True ----- ADV
#  all ----- all ----- True ----- DET
#  three ----- three ----- True ----- NUM
#  of ----- of ----- True ----- ADP
#  them ----- -PRON- ----- True ----- PRON
#  had ----- have ----- True ----- AUX
#  received ----- receive ----- False ----- VERB
#  their ----- -PRON- ----- True ----- DET
#  shots ----- shot ----- False ----- NOUN
#  . ----- . ----- False ----- PUNCT

# %% [markdown]
# ### Extract keywords (filter out keywords)

# %%
# init blank keyword list 
keyword = []

for token in doc:
    # check if current token is a stop word or punctuation, if yes then skip
    if token.text in nlp.Defaults.stop_words or token.text in punctuation:
        continue

    # if token text is Noun, Verb, Adjective or Propernoun, save to keywords list
    elif token.pos_ in ['NOUN','VERB','ADJ','PROPN']:
       keyword.append(token.text)

# check populated keyword list
keyword
# Out:
# ['vice',
#  'president',
#  'mike',
#  'pence',
#  'administered',
#  'vaccine',
#  'televised',
#  'event',
#  'friday',
#  'member',
#  'trump',
#  'administration',
#  'known',
#  'received',
#  'shot',
#  'mr',
#  'pence',
#  'said',
#  'hoped',
#  'vaccination',
#  'help',
#  'build',
#  'public',
#  'confidence',
#  'vaccine',
#  'safe',
#  'effective',
#  'known',
#  'president',
#  'trump',
#  'lady',
#  'melania',
#  'trump',
#  'contracted',
#  'covid-19',
#  'fall',
#  'receive',
#  'vaccine',
#  'coming',
#  'weeks',
#  'white',
#  'house',
#  'press',
#  'secretary',
#  'kayleigh',
#  'mcenany',
#  'said',
#  'week',
#  'president',
#  'open',
#  'taking',
#  'vaccine',
#  'wants',
#  'americans',
#  'priority',
#  'vulnerable',
#  'president',
#  'elect',
#  'joe',
#  'biden',
#  'wife',
#  'jill',
#  'biden',
#  'vaccine',
#  'public',
#  'monday',
#  'transition',
#  'team',
#  'said',
#  'transition',
#  'team',
#  'said',
#  'vice',
#  'president',
#  'elect',
#  'kamala',
#  'harris',
#  'husband',
#  'doug',
#  'emhoff',
#  'receive',
#  'vaccine',
#  'following',
#  'week',
#  'mr',
#  'pence',
#  'received',
#  'doses',
#  'second',
#  'lady',
#  'karen',
#  'pence',
#  'surgeon',
#  'general',
#  'jerome',
#  'adams',
#  'event',
#  'held',
#  'eisenhower',
#  'executive',
#  'office',
#  'building',
#  'signs',
#  'reading',
#  'safe',
#  'effective',
#  'dr',
#  'adams',
#  'flashed',
#  'vice',
#  'president',
#  'thumbs',
#  'received',
#  'shots']

# %% [markdown]
# ### Normalize weightage of keywords
#
# ##### Get frequency of each word
#
# - `Counter` will convert the list into a dictionary with their respective frequency values

# %%
# get frequency of each word
freq_of_keywords = Counter(keyword)

# pretty print frequency of words 
pprint.pprint(freq_of_keywords)
# Out:
# Counter({'president': 6,
#          'vaccine': 6,
#          'pence': 4,
#          'said': 4,
#          'vice': 3,
#          'trump': 3,
#          'received': 3,
#          'event': 2,
#          'known': 2,
#          'mr': 2,
#          'public': 2,
#          'safe': 2,
#          'effective': 2,
#          'lady': 2,
#          'receive': 2,
#          'week': 2,
#          'elect': 2,
#          'biden': 2,
#          'transition': 2,
#          'team': 2,
#          'adams': 2,
#          'mike': 1,
#          'administered': 1,
#          'televised': 1,
#          'friday': 1,
#          'member': 1,
#          'administration': 1,
#          'shot': 1,
#          'hoped': 1,
#          'vaccination': 1,
#          'help': 1,
#          'build': 1,
#          'confidence': 1,
#          'melania': 1,
#          'contracted': 1,
#          'covid-19': 1,
#          'fall': 1,
#          'coming': 1,
#          'weeks': 1,
#          'white': 1,
#          'house': 1,
#          'press': 1,
#          'secretary': 1,
#          'kayleigh': 1,
#          'mcenany': 1,
#          'open': 1,
#          'taking': 1,
#          'wants': 1,
#          'americans': 1,
#          'priority': 1,
#          'vulnerable': 1,
#          'joe': 1,
#          'wife': 1,
#          'jill': 1,
#          'monday': 1,
#          'kamala': 1,
#          'harris': 1,
#          'husband': 1,
#          'doug': 1,
#          'emhoff': 1,
#          'following': 1,
#          'doses': 1,
#          'second': 1,
#          'karen': 1,
#          'surgeon': 1,
#          'general': 1,
#          'jerome': 1,
#          'held': 1,
#          'eisenhower': 1,
#          'executive': 1,
#          'office': 1,
#          'building': 1,
#          'signs': 1,
#          'reading': 1,
#          'dr': 1,
#          'flashed': 1,
#          'thumbs': 1,
#          'shots': 1})

# %% [markdown]
# ##### Sort by frequency - most common to least common

# %%
# get the most frequent keyword
sort_occurence = freq_of_keywords.most_common()
pprint.pprint(sort_occurence)
# Out:
# [('president', 6),
#  ('vaccine', 6),
#  ('pence', 4),
#  ('said', 4),
#  ('vice', 3),
#  ('trump', 3),
#  ('received', 3),
#  ('event', 2),
#  ('known', 2),
#  ('mr', 2),
#  ('public', 2),
#  ('safe', 2),
#  ('effective', 2),
#  ('lady', 2),
#  ('receive', 2),
#  ('week', 2),
#  ('elect', 2),
#  ('biden', 2),
#  ('transition', 2),
#  ('team', 2),
#  ('adams', 2),
#  ('mike', 1),
#  ('administered', 1),
#  ('televised', 1),
#  ('friday', 1),
#  ('member', 1),
#  ('administration', 1),
#  ('shot', 1),
#  ('hoped', 1),
#  ('vaccination', 1),
#  ('help', 1),
#  ('build', 1),
#  ('confidence', 1),
#  ('melania', 1),
#  ('contracted', 1),
#  ('covid-19', 1),
#  ('fall', 1),
#  ('coming', 1),
#  ('weeks', 1),
#  ('white', 1),
#  ('house', 1),
#  ('press', 1),
#  ('secretary', 1),
#  ('kayleigh', 1),
#  ('mcenany', 1),
#  ('open', 1),
#  ('taking', 1),
#  ('wants', 1),
#  ('americans', 1),
#  ('priority', 1),
#  ('vulnerable', 1),
#  ('joe', 1),
#  ('wife', 1),
#  ('jill', 1),
#  ('monday', 1),
#  ('kamala', 1),
#  ('harris', 1),
#  ('husband', 1),
#  ('doug', 1),
#  ('emhoff', 1),
#  ('following', 1),
#  ('doses', 1),
#  ('second', 1),
#  ('karen', 1),
#  ('surgeon', 1),
#  ('general', 1),
#  ('jerome', 1),
#  ('held', 1),
#  ('eisenhower', 1),
#  ('executive', 1),
#  ('office', 1),
#  ('building', 1),
#  ('signs', 1),
#  ('reading', 1),
#  ('dr', 1),
#  ('flashed', 1),
#  ('thumbs', 1),
#  ('shots', 1)]

# %% [markdown]
# ##### Get the most common word

# %%
print(sort_occurence[0])
# Out:
# ('president', 6)

# %% [markdown]
# ##### Get frequency of most common word

# %%
max_frequency = sort_occurence[0][1]
print(max_frequency)
# Out:
# 6

# %% [markdown]
# ##### Normalize frequency of each keyword with the max frequency value

# %%
for word in freq_of_keywords:
    freq_of_keywords[word] = freq_of_keywords[word]/max_frequency

print('Normalized TF:'+'-'*50,'\n')
pprint.pprint(freq_of_keywords)
# Out:
# Normalized TF:--------------------------------------------------
#
# Counter({'president': 1.0,
#          'vaccine': 1.0,
#          'pence': 0.6666666666666666,
#          'said': 0.6666666666666666,
#          'vice': 0.5,
#          'trump': 0.5,
#          'received': 0.5,
#          'event': 0.3333333333333333,
#          'known': 0.3333333333333333,
#          'mr': 0.3333333333333333,
#          'public': 0.3333333333333333,
#          'safe': 0.3333333333333333,
#          'effective': 0.3333333333333333,
#          'lady': 0.3333333333333333,
#          'receive': 0.3333333333333333,
#          'week': 0.3333333333333333,
#          'elect': 0.3333333333333333,
#          'biden': 0.3333333333333333,
#          'transition': 0.3333333333333333,
#          'team': 0.3333333333333333,
#          'adams': 0.3333333333333333,
#          'mike': 0.16666666666666666,
#          'administered': 0.16666666666666666,
#          'televised': 0.16666666666666666,
#          'friday': 0.16666666666666666,
#          'member': 0.16666666666666666,
#          'administration': 0.16666666666666666,
#          'shot': 0.16666666666666666,
#          'hoped': 0.16666666666666666,
#          'vaccination': 0.16666666666666666,
#          'help': 0.16666666666666666,
#          'build': 0.16666666666666666,
#          'confidence': 0.16666666666666666,
#          'melania': 0.16666666666666666,
#          'contracted': 0.16666666666666666,
#          'covid-19': 0.16666666666666666,
#          'fall': 0.16666666666666666,
#          'coming': 0.16666666666666666,
#          'weeks': 0.16666666666666666,
#          'white': 0.16666666666666666,
#          'house': 0.16666666666666666,
#          'press': 0.16666666666666666,
#          'secretary': 0.16666666666666666,
#          'kayleigh': 0.16666666666666666,
#          'mcenany': 0.16666666666666666,
#          'open': 0.16666666666666666,
#          'taking': 0.16666666666666666,
#          'wants': 0.16666666666666666,
#          'americans': 0.16666666666666666,
#          'priority': 0.16666666666666666,
#          'vulnerable': 0.16666666666666666,
#          'joe': 0.16666666666666666,
#          'wife': 0.16666666666666666,
#          'jill': 0.16666666666666666,
#          'monday': 0.16666666666666666,
#          'kamala': 0.16666666666666666,
#          'harris': 0.16666666666666666,
#          'husband': 0.16666666666666666,
#          'doug': 0.16666666666666666,
#          'emhoff': 0.16666666666666666,
#          'following': 0.16666666666666666,
#          'doses': 0.16666666666666666,
#          'second': 0.16666666666666666,
#          'karen': 0.16666666666666666,
#          'surgeon': 0.16666666666666666,
#          'general': 0.16666666666666666,
#          'jerome': 0.16666666666666666,
#          'held': 0.16666666666666666,
#          'eisenhower': 0.16666666666666666,
#          'executive': 0.16666666666666666,
#          'office': 0.16666666666666666,
#          'building': 0.16666666666666666,
#          'signs': 0.16666666666666666,
#          'reading': 0.16666666666666666,
#          'dr': 0.16666666666666666,
#          'flashed': 0.16666666666666666,
#          'thumbs': 0.16666666666666666,
#          'shots': 0.16666666666666666})

# %% [markdown]
# ### Sentence Importance Computation

# %% [markdown]
# ##### Extract all sentences

# %%
for sentence in doc.sents:
    print('-'*150)
    pprint.pprint(sentence)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# vice president mike pence was administered the covid-19 vaccine in a televised event friday, becoming the senior-most member of the trump administration known to have received the shot.
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# mr. pence said he hoped his vaccination would help to build public confidence that the vaccine was safe and effective.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# it isn’t known whether president trump and first lady melania trump, who both contracted covid-19 this fall, will receive the vaccine in the coming weeks.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# white house press secretary kayleigh mcenany said this week that the president is open to taking the vaccine but “wants to show americans that our priority are the most vulnerable.”
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# president-elect joe biden and his wife, jill biden, will get the vaccine in public on monday, his transition team said.
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# the transition team said vice president-elect kamala harris and her husband, doug emhoff, would receive the vaccine the following week.
#
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# mr. pence received his first of two doses alongside second lady karen pence and surgeon general jerome adams, in an event held in the eisenhower executive office building, in front of two signs reading “safe and effective.”
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# dr. adams flashed the vice president a thumbs-up after all three of them had received their shots.

# %%
# access each word in each sentence
for sentence in doc.sents:
    print('='*150)
    for word in sentence:
        print('---'*10)
        print(word, ', type:' ,type(word))
# Out:
# ======================================================================================================================================================
# ------------------------------
# vice , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# president , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# mike , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# pence , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# was , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# administered , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# covid-19 , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# vaccine , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# a , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# televised , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# event , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# friday , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# becoming , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# senior , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# - , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# most , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# member , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# trump , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# administration , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# known , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# have , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# received , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# shot , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
#
#
#  , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# mr , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# pence , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# said , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# he , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# hoped , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# his , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# vaccination , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# would , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# help , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# build , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# public , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# confidence , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# that , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# vaccine , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# was , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# safe , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# and , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# effective , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# it , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# is , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# n’t , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# known , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# whether , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# president , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# trump , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# and , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# first , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# lady , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# melania , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# trump , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# who , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# both , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# contracted , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# covid-19 , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# this , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# fall , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# will , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# receive , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# vaccine , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# coming , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# weeks , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# white , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# house , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# press , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# secretary , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# kayleigh , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# mcenany , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# said , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# this , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# week , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# that , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# president , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# is , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# open , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# taking , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# vaccine , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# but , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# “ , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# wants , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# show , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# americans , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# that , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# our , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# priority , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# are , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# most , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# vulnerable , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ” , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
#
#
#  , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# president , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# - , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# elect , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# joe , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# biden , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# and , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# his , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# wife , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# jill , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# biden , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# will , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# get , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# vaccine , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# public , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# on , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# monday , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# his , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# transition , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# team , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# said , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
#
#
#  , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# transition , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# team , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# said , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# vice , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# president , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# - , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# elect , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# kamala , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# harris , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# and , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# her , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# husband , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# doug , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# emhoff , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# would , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# receive , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# vaccine , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# following , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# week , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
#
#
#  , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# mr , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# pence , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# received , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# his , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# first , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# two , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# doses , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# alongside , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# second , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# lady , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# karen , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# pence , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# and , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# surgeon , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# general , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# jerome , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# adams , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# an , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# event , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# held , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# eisenhower , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# executive , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# office , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# building , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# front , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# two , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# signs , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# reading , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# “ , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# safe , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# and , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# effective , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ” , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# dr , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# adams , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# flashed , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# vice , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# president , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# a , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# thumbs , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# - , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# up , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# after , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# all , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# three , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# them , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# had , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# received , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# their , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# shots , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>

# %% [markdown]
# ##### Exploratory Sentence-Word Analysis

# %%
# access each word in each sentence 
# check if word is in list of keywords
for sentence in doc.sents:
    print('='*150)
    for word in sentence:
        print('---'*15)
        print(word.text)
        print('keyword? = ', word.text in freq_of_keywords.keys()) # check if word text is a keyword
        print('stop-word? = ', word.is_stop ) # check if word-token is a stop word
# Out:
# ======================================================================================================================================================
# ---------------------------------------------
# vice
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# president
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# mike
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# pence
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# was
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# administered
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# covid-19
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# vaccine
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# a
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# televised
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# event
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# friday
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# becoming
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# senior
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# -
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# most
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# member
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# trump
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# administration
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# known
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# have
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# received
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# shot
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
#
#
#
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# mr
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# pence
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# said
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# he
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# hoped
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# his
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# vaccination
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# would
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# help
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# build
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# public
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# confidence
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# that
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# vaccine
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# was
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# safe
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# and
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# effective
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# it
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# is
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# n’t
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# known
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# whether
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# president
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# trump
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# and
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# first
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# lady
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# melania
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# trump
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# who
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# both
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# contracted
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# covid-19
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# this
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# fall
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# will
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# receive
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# vaccine
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# coming
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# weeks
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# white
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# house
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# press
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# secretary
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# kayleigh
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# mcenany
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# said
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# this
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# week
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# that
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# president
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# is
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# open
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# taking
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# vaccine
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# but
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# “
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# wants
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# show
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# americans
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# that
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# our
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# priority
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# are
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# most
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# vulnerable
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# ”
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
#
#
#
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# president
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# -
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# elect
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# joe
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# biden
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# and
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# his
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# wife
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# jill
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# biden
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# will
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# get
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# vaccine
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# public
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# on
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# monday
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# his
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# transition
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# team
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# said
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
#
#
#
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# transition
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# team
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# said
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# vice
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# president
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# -
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# elect
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# kamala
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# harris
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# and
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# her
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# husband
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# doug
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# emhoff
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# would
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# receive
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# vaccine
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# following
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# week
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
#
#
#
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# mr
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# pence
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# received
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# his
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# first
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# two
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# doses
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# alongside
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# second
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# lady
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# karen
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# pence
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# and
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# surgeon
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# general
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# jerome
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# adams
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# an
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# event
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# held
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# eisenhower
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# executive
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# office
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# building
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# front
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# two
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# signs
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# reading
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# “
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# safe
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# and
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# effective
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# ”
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# dr
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# adams
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# flashed
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# vice
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# president
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# a
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# thumbs
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# -
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# up
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# after
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# all
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# three
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# them
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# had
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# received
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# their
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# shots
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False

# %% [markdown]
# ##### Calculate the importance of the sentences
#
# - identify occurence of important keywords in each sentence
#
# - then, sum up the value to weight each sentence

# %%
# initialize dictionary to accumulate strength for each sentence
sentence_strength = {}

# %% [markdown]
# - for a given sentence
#
#     - each time a word is found in the `freq_of_keywords` dictionary
#
#     - add the frequency of the word to the sentence strength

# %%
# loop over each sentence in document
for sentence in doc.sents:

    # loop over each word in current sentence 
    for word in sentence: 

        # check if current word is in important keyword list
        if word.text in freq_of_keywords.keys():

            # check if current sentence is present in sentence_strength dictionary 
            if sentence in sentence_strength.keys():

                # increase weight of sentence by normalized frequency of the current word
                sentence_strength[sentence] += freq_of_keywords[word.text]

            # if sentence is not in the sentence_strength dictionary
            else:
                
                # create key entry for current sentence and set the value to current word's normalized frequecy
                sentence_strength[sentence] = freq_of_keywords[word.text]

pprint.pprint(sentence_strength)
# Out:
# {vice president mike pence was administered the covid-19 vaccine in a televised event friday, becoming the senior-most member of the trump administration known to have received the shot.
#
# : 6.166666666666667,
#  mr. pence said he hoped his vaccination would help to build public confidence that the vaccine was safe and effective.: 4.499999999999999,
#  it isn’t known whether president trump and first lady melania trump, who both contracted covid-19 this fall, will receive the vaccine in the coming weeks.: 5.0,
#  white house press secretary kayleigh mcenany said this week that the president is open to taking the vaccine but “wants to show americans that our priority are the most vulnerable.”
#
# : 5.000000000000001,
#  president-elect joe biden and his wife, jill biden, will get the vaccine in public on monday, his transition team said.
#
# : 5.333333333333333,
#  the transition team said vice president-elect kamala harris and her husband, doug emhoff, would receive the vaccine the following week.
#
# : 5.833333333333332,
#  mr. pence received his first of two doses alongside second lady karen pence and surgeon general jerome adams, in an event held in the eisenhower executive office building, in front of two signs reading “safe and effective.”: 6.000000000000001,
#  dr. adams flashed the vice president a thumbs-up after all three of them had received their shots.: 2.9999999999999996}

# %% [markdown]
# ### Sort the sentences by their strengths (importance)

# %%
sorted_sentence_strengths = sorted(sentence_strength.items(), key = lambda key_value: key_value[1], reverse=True)
pprint.pprint(sorted_sentence_strengths)
# Out:
# [(vice president mike pence was administered the covid-19 vaccine in a televised event friday, becoming the senior-most member of the trump administration known to have received the shot.
#
# ,
#   6.166666666666667),
#  (mr. pence received his first of two doses alongside second lady karen pence and surgeon general jerome adams, in an event held in the eisenhower executive office building, in front of two signs reading “safe and effective.”,
#   6.000000000000001),
#  (the transition team said vice president-elect kamala harris and her husband, doug emhoff, would receive the vaccine the following week.
#
# ,
#   5.833333333333332),
#  (president-elect joe biden and his wife, jill biden, will get the vaccine in public on monday, his transition team said.
#
# ,
#   5.333333333333333),
#  (white house press secretary kayleigh mcenany said this week that the president is open to taking the vaccine but “wants to show americans that our priority are the most vulnerable.”
#
# ,
#   5.000000000000001),
#  (it isn’t known whether president trump and first lady melania trump, who both contracted covid-19 this fall, will receive the vaccine in the coming weeks.,
#   5.0),
#  (mr. pence said he hoped his vaccination would help to build public confidence that the vaccine was safe and effective.,
#   4.499999999999999),
#  (dr. adams flashed the vice president a thumbs-up after all three of them had received their shots.,
#   2.9999999999999996)]

# %% [markdown]
# ### Set summary sentence limit

# %%
num_summary_sentences = 3

# %% [markdown]
# ##### Extract the first `num_summary_sentences` from the `soreted_sentence_strength` list

# %%
if num_summary_sentences <= len(sorted_sentence_strengths):
    summary_sentence_set = sorted_sentence_strengths[:num_summary_sentences]
else: 
    print('Number of sentences required in summary is more than sentences in original text!')

pprint.pprint(summary_sentence_set)
# Out:
# [(vice president mike pence was administered the covid-19 vaccine in a televised event friday, becoming the senior-most member of the trump administration known to have received the shot.
#
# ,
#   6.166666666666667),
#  (mr. pence received his first of two doses alongside second lady karen pence and surgeon general jerome adams, in an event held in the eisenhower executive office building, in front of two signs reading “safe and effective.”,
#   6.000000000000001),
#  (the transition team said vice president-elect kamala harris and her husband, doug emhoff, would receive the vaccine the following week.
#
# ,
#   5.833333333333332)]

# %% [markdown]
# ### Generate final summary
#
# - by cleaning up the extracted sentence list

# %%
summary = ' '.join([ item[0].text.capitalize() for item in summary_sentence_set ])
print(summary)
# Out:
# Vice president mike pence was administered the covid-19 vaccine in a televised event friday, becoming the senior-most member of the trump administration known to have received the shot.
#
#  Mr. pence received his first of two doses alongside second lady karen pence and surgeon general jerome adams, in an event held in the eisenhower executive office building, in front of two signs reading “safe and effective.” The transition team said vice president-elect kamala harris and her husband, doug emhoff, would receive the vaccine the following week.
