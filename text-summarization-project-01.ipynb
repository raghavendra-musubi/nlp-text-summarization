# %% [markdown]
# ### Reference
#
# - [Extractive Text Summarization Using spaCy in Python](https://medium.com/better-programming/extractive-text-summarization-using-spacy-in-python-88ab96d1fd97)

# %% [markdown]
# # TF-IDF
#
# - TF-IDF *(Term Frequency-Inverse Data Frequency)* is used to calculate the importance of a sentence for text summarization in
#
#     - *information retrieval* and
#
#     - *text mining*
#
#
# ## TF: Term Frequency
#
# - measure of frequency of a term in a document
#
# *normalization*
#
# - since every document is different in length, it is possible that a term would appear many more times in long documents than shorter ones
#
# - thus, *the term frequency is often divided by the document length* (such as the total number of terms in the document) as a way of normalization
#
#
#
# ## IDF: Inverse Document Frequency
#
# - measures how important a term is
#
# *stopwords*
#
# - while computing the term frequency (TF), all terms are considered equally important
#
# - however, it is known that certain terms may appear a lot of times but have little importance in the document
#     - For example: is, are, they, and so on
#     - these are called stopwords

# %% [markdown]
# ### TF-IDF Limitations
#
# - A common term in a domain might be an important term in another domain
#
#     - As the saying goes: “One man’s meat is another man’s poison”
#
# - TF-IDF is not a good choice if you are dealing with multiple domains
#
#     -  A unbalanced dataset tends to be biased and it will greatly affect the result

# %% [markdown]
# # Identifying top sentences in an article (Text Summarization)

# %% [markdown]
# Following are the steps in text summarization:
#
# 1. tokenize article using spacy's language model
#
# 2. extract important keywords and normalize weight
#
# 3. calculate importance of each sentence in the article based on keyword appearance
#
# 4. sort the sentence based on the calculated importance

# %% [markdown]
# ## Implementation

# %%
# conduct imports
import spacy 
from collections import Counter
from string import punctuation
import pprint

# %% [markdown]
# ### Load SpaCy Model

# %%
# load large english web model
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ### Text to summarize

# %%
input_text = '''Yamaha is reminding people that musical equipment cases are for musical equipment — not people — two weeks after fugitive auto titan Carlos Ghosn reportedly was smuggled out of Japan in one. In a tweet over the weekend, the Japanese musical equipment company said it was not naming any names, but noted there had been many recent stories about people getting into musical equipment cases. Yamaha (YAMCY) warned people not to get into, or let others get into, its cases to avoid "unfortunate accidents." Multiple media outlets have reported that Ghosn managed to sneak through a Japanese airport to a private jet that whisked him out of the country by hiding in a large, black music equipment case with breathing holes drilled in the bottom. CNN Business has not independently confirmed those details of his escape. The former Nissan (NSANF) CEO had been out on bail awaiting trial in Japan on charges of financial wrongdoing before making his stunning escape to Lebanon at the end of December. Ghosn has referred to his departure as an effort to "escape injustice." In an interview with CNN\'s Richard Quest last week, Ghosn did not comment on the nature of his escape, saying he didn\'t want to endanger any of the people who aided in the operation. Ghosn did, however, respond to a question about what it felt like to ride through the airport in a packing case by first declining to comment but then adding: "Freedom, no matter the way it happens, is always sweet." In a press conference in Lebanon ahead of the CNN interview last Wednesday, Ghosn\'s first public appearance since fleeing Japan, Ghosn said he decided to leave the country because he believed he would not receive a fair trial, a claim Japanese authorities have disputed. Brands sometimes capitalize on their tangential relationship to big news in order to attract attention on social media. Yamaha is one of Japan\'s best known brands and Ghosn was one of Japan\'s top executives before being ousted from Nissan — a match made in social media heaven. Not surprisingly, Yamaha\'s post went viral on Twitter over the weekend.'''

# %% [markdown]
# ### Tokenize text

# %%
doc = nlp(input_text.lower())

# %% [markdown]
# ### Explore the tokens

# %%
print("token ----- lemma_ ----- is_stop? ----- part-of-speech")
print('='*75)
for token in doc:
    print(f" {str(token)} ----- {str(token.lemma_)} ----- {str(token.is_stop)} ----- {str(token.pos_)}")
# Out:
# token ----- lemma_ ----- is_stop? ----- part-of-speech
# ===========================================================================
#  yamaha ----- yamaha ----- False ----- PROPN
#  is ----- be ----- True ----- AUX
#  reminding ----- remind ----- False ----- VERB
#  people ----- people ----- False ----- NOUN
#  that ----- that ----- True ----- SCONJ
#  musical ----- musical ----- False ----- ADJ
#  equipment ----- equipment ----- False ----- NOUN
#  cases ----- case ----- False ----- NOUN
#  are ----- be ----- True ----- AUX
#  for ----- for ----- True ----- ADP
#  musical ----- musical ----- False ----- ADJ
#  equipment ----- equipment ----- False ----- NOUN
#  — ----- — ----- False ----- PUNCT
#  not ----- not ----- True ----- PART
#  people ----- people ----- False ----- NOUN
#  — ----- — ----- False ----- PUNCT
#  two ----- two ----- True ----- NUM
#  weeks ----- week ----- False ----- NOUN
#  after ----- after ----- True ----- ADP
#  fugitive ----- fugitive ----- False ----- ADJ
#  auto ----- auto ----- False ----- PROPN
#  titan ----- titan ----- False ----- PROPN
#  carlos ----- carlos ----- False ----- PROPN
#  ghosn ----- ghosn ----- False ----- PROPN
#  reportedly ----- reportedly ----- False ----- ADV
#  was ----- be ----- True ----- AUX
#  smuggled ----- smuggle ----- False ----- VERB
#  out ----- out ----- True ----- SCONJ
#  of ----- of ----- True ----- ADP
#  japan ----- japan ----- False ----- PROPN
#  in ----- in ----- True ----- ADP
#  one ----- one ----- True ----- NUM
#  . ----- . ----- False ----- PUNCT
#  in ----- in ----- True ----- ADP
#  a ----- a ----- True ----- DET
#  tweet ----- tweet ----- False ----- NOUN
#  over ----- over ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  weekend ----- weekend ----- False ----- NOUN
#  , ----- , ----- False ----- PUNCT
#  the ----- the ----- True ----- DET
#  japanese ----- japanese ----- False ----- ADJ
#  musical ----- musical ----- False ----- ADJ
#  equipment ----- equipment ----- False ----- NOUN
#  company ----- company ----- False ----- NOUN
#  said ----- say ----- False ----- VERB
#  it ----- -PRON- ----- True ----- PRON
#  was ----- be ----- True ----- AUX
#  not ----- not ----- True ----- PART
#  naming ----- name ----- False ----- VERB
#  any ----- any ----- True ----- DET
#  names ----- name ----- False ----- NOUN
#  , ----- , ----- False ----- PUNCT
#  but ----- but ----- True ----- CCONJ
#  noted ----- note ----- False ----- VERB
#  there ----- there ----- True ----- PRON
#  had ----- have ----- True ----- AUX
#  been ----- be ----- True ----- AUX
#  many ----- many ----- True ----- ADJ
#  recent ----- recent ----- False ----- ADJ
#  stories ----- story ----- False ----- NOUN
#  about ----- about ----- True ----- ADP
#  people ----- people ----- False ----- NOUN
#  getting ----- get ----- False ----- VERB
#  into ----- into ----- True ----- ADP
#  musical ----- musical ----- False ----- ADJ
#  equipment ----- equipment ----- False ----- NOUN
#  cases ----- case ----- False ----- NOUN
#  . ----- . ----- False ----- PUNCT
#  yamaha ----- yamaha ----- False ----- PROPN
#  ( ----- ( ----- False ----- PUNCT
#  yamcy ----- yamcy ----- False ----- PROPN
#  ) ----- ) ----- False ----- PUNCT
#  warned ----- warn ----- False ----- VERB
#  people ----- people ----- False ----- NOUN
#  not ----- not ----- True ----- PART
#  to ----- to ----- True ----- PART
#  get ----- get ----- True ----- AUX
#  into ----- into ----- True ----- ADP
#  , ----- , ----- False ----- PUNCT
#  or ----- or ----- True ----- CCONJ
#  let ----- let ----- False ----- VERB
#  others ----- other ----- True ----- NOUN
#  get ----- get ----- True ----- AUX
#  into ----- into ----- True ----- ADP
#  , ----- , ----- False ----- PUNCT
#  its ----- -PRON- ----- True ----- DET
#  cases ----- case ----- False ----- NOUN
#  to ----- to ----- True ----- PART
#  avoid ----- avoid ----- False ----- VERB
#  " ----- " ----- False ----- PUNCT
#  unfortunate ----- unfortunate ----- False ----- ADJ
#  accidents ----- accident ----- False ----- NOUN
#  . ----- . ----- False ----- PUNCT
#  " ----- " ----- False ----- PUNCT
#  multiple ----- multiple ----- False ----- ADJ
#  media ----- medium ----- False ----- NOUN
#  outlets ----- outlet ----- False ----- NOUN
#  have ----- have ----- True ----- AUX
#  reported ----- report ----- False ----- VERB
#  that ----- that ----- True ----- SCONJ
#  ghosn ----- ghosn ----- False ----- PROPN
#  managed ----- manage ----- False ----- VERB
#  to ----- to ----- True ----- PART
#  sneak ----- sneak ----- False ----- VERB
#  through ----- through ----- True ----- ADP
#  a ----- a ----- True ----- DET
#  japanese ----- japanese ----- False ----- ADJ
#  airport ----- airport ----- False ----- NOUN
#  to ----- to ----- True ----- ADP
#  a ----- a ----- True ----- DET
#  private ----- private ----- False ----- ADJ
#  jet ----- jet ----- False ----- NOUN
#  that ----- that ----- True ----- DET
#  whisked ----- whisk ----- False ----- VERB
#  him ----- -PRON- ----- True ----- PRON
#  out ----- out ----- True ----- SCONJ
#  of ----- of ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  country ----- country ----- False ----- NOUN
#  by ----- by ----- True ----- ADP
#  hiding ----- hide ----- False ----- VERB
#  in ----- in ----- True ----- ADP
#  a ----- a ----- True ----- DET
#  large ----- large ----- False ----- ADJ
#  , ----- , ----- False ----- PUNCT
#  black ----- black ----- False ----- ADJ
#  music ----- music ----- False ----- NOUN
#  equipment ----- equipment ----- False ----- NOUN
#  case ----- case ----- False ----- NOUN
#  with ----- with ----- True ----- ADP
#  breathing ----- breathing ----- False ----- NOUN
#  holes ----- hole ----- False ----- NOUN
#  drilled ----- drill ----- False ----- VERB
#  in ----- in ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  bottom ----- bottom ----- True ----- NOUN
#  . ----- . ----- False ----- PUNCT
#  cnn ----- cnn ----- False ----- PROPN
#  business ----- business ----- False ----- NOUN
#  has ----- have ----- True ----- AUX
#  not ----- not ----- True ----- PART
#  independently ----- independently ----- False ----- ADV
#  confirmed ----- confirm ----- False ----- VERB
#  those ----- those ----- True ----- DET
#  details ----- detail ----- False ----- NOUN
#  of ----- of ----- True ----- ADP
#  his ----- -PRON- ----- True ----- DET
#  escape ----- escape ----- False ----- NOUN
#  . ----- . ----- False ----- PUNCT
#  the ----- the ----- True ----- DET
#  former ----- former ----- True ----- ADJ
#  nissan ----- nissan ----- False ----- PROPN
#  ( ----- ( ----- False ----- PUNCT
#  nsanf ----- nsanf ----- False ----- PROPN
#  ) ----- ) ----- False ----- PUNCT
#  ceo ----- ceo ----- False ----- PROPN
#  had ----- have ----- True ----- AUX
#  been ----- be ----- True ----- AUX
#  out ----- out ----- True ----- ADP
#  on ----- on ----- True ----- ADP
#  bail ----- bail ----- False ----- NOUN
#  awaiting ----- await ----- False ----- VERB
#  trial ----- trial ----- False ----- NOUN
#  in ----- in ----- True ----- ADP
#  japan ----- japan ----- False ----- PROPN
#  on ----- on ----- True ----- ADP
#  charges ----- charge ----- False ----- NOUN
#  of ----- of ----- True ----- ADP
#  financial ----- financial ----- False ----- ADJ
#  wrongdoing ----- wrongdoing ----- False ----- NOUN
#  before ----- before ----- True ----- ADP
#  making ----- make ----- False ----- VERB
#  his ----- -PRON- ----- True ----- DET
#  stunning ----- stunning ----- False ----- ADJ
#  escape ----- escape ----- False ----- NOUN
#  to ----- to ----- True ----- ADP
#  lebanon ----- lebanon ----- False ----- PROPN
#  at ----- at ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  end ----- end ----- False ----- NOUN
#  of ----- of ----- True ----- ADP
#  december ----- december ----- False ----- PROPN
#  . ----- . ----- False ----- PUNCT
#  ghosn ----- ghosn ----- False ----- PROPN
#  has ----- have ----- True ----- AUX
#  referred ----- refer ----- False ----- VERB
#  to ----- to ----- True ----- ADP
#  his ----- -PRON- ----- True ----- DET
#  departure ----- departure ----- False ----- NOUN
#  as ----- as ----- True ----- SCONJ
#  an ----- an ----- True ----- DET
#  effort ----- effort ----- False ----- NOUN
#  to ----- to ----- True ----- PART
#  " ----- " ----- False ----- PUNCT
#  escape ----- escape ----- False ----- VERB
#  injustice ----- injustice ----- False ----- NOUN
#  . ----- . ----- False ----- PUNCT
#  " ----- " ----- False ----- PUNCT
#  in ----- in ----- True ----- ADP
#  an ----- an ----- True ----- DET
#  interview ----- interview ----- False ----- NOUN
#  with ----- with ----- True ----- ADP
#  cnn ----- cnn ----- False ----- PROPN
#  's ----- 's ----- True ----- PART
#  richard ----- richard ----- False ----- PROPN
#  quest ----- quest ----- False ----- PROPN
#  last ----- last ----- True ----- ADJ
#  week ----- week ----- False ----- NOUN
#  , ----- , ----- False ----- PUNCT
#  ghosn ----- ghosn ----- False ----- PROPN
#  did ----- do ----- True ----- AUX
#  not ----- not ----- True ----- PART
#  comment ----- comment ----- False ----- VERB
#  on ----- on ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  nature ----- nature ----- False ----- NOUN
#  of ----- of ----- True ----- ADP
#  his ----- -PRON- ----- True ----- DET
#  escape ----- escape ----- False ----- NOUN
#  , ----- , ----- False ----- PUNCT
#  saying ----- say ----- False ----- VERB
#  he ----- -PRON- ----- True ----- PRON
#  did ----- do ----- True ----- AUX
#  n't ----- not ----- True ----- PART
#  want ----- want ----- False ----- VERB
#  to ----- to ----- True ----- PART
#  endanger ----- endanger ----- False ----- VERB
#  any ----- any ----- True ----- DET
#  of ----- of ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  people ----- people ----- False ----- NOUN
#  who ----- who ----- True ----- PRON
#  aided ----- aid ----- False ----- VERB
#  in ----- in ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  operation ----- operation ----- False ----- NOUN
#  . ----- . ----- False ----- PUNCT
#  ghosn ----- ghosn ----- False ----- PROPN
#  did ----- do ----- True ----- AUX
#  , ----- , ----- False ----- PUNCT
#  however ----- however ----- True ----- ADV
#  , ----- , ----- False ----- PUNCT
#  respond ----- respond ----- False ----- VERB
#  to ----- to ----- True ----- ADP
#  a ----- a ----- True ----- DET
#  question ----- question ----- False ----- NOUN
#  about ----- about ----- True ----- ADP
#  what ----- what ----- True ----- PRON
#  it ----- -PRON- ----- True ----- PRON
#  felt ----- feel ----- False ----- VERB
#  like ----- like ----- False ----- SCONJ
#  to ----- to ----- True ----- PART
#  ride ----- ride ----- False ----- VERB
#  through ----- through ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  airport ----- airport ----- False ----- NOUN
#  in ----- in ----- True ----- ADP
#  a ----- a ----- True ----- DET
#  packing ----- packing ----- False ----- NOUN
#  case ----- case ----- False ----- NOUN
#  by ----- by ----- True ----- ADP
#  first ----- first ----- True ----- ADV
#  declining ----- decline ----- False ----- VERB
#  to ----- to ----- True ----- PART
#  comment ----- comment ----- False ----- VERB
#  but ----- but ----- True ----- CCONJ
#  then ----- then ----- True ----- ADV
#  adding ----- add ----- False ----- VERB
#  : ----- : ----- False ----- PUNCT
#  " ----- " ----- False ----- PUNCT
#  freedom ----- freedom ----- False ----- NOUN
#  , ----- , ----- False ----- PUNCT
#  no ----- no ----- True ----- ADV
#  matter ----- matter ----- False ----- ADV
#  the ----- the ----- True ----- DET
#  way ----- way ----- False ----- NOUN
#  it ----- -PRON- ----- True ----- PRON
#  happens ----- happen ----- False ----- VERB
#  , ----- , ----- False ----- PUNCT
#  is ----- be ----- True ----- AUX
#  always ----- always ----- True ----- ADV
#  sweet ----- sweet ----- False ----- ADJ
#  . ----- . ----- False ----- PUNCT
#  " ----- " ----- False ----- PUNCT
#  in ----- in ----- True ----- ADP
#  a ----- a ----- True ----- DET
#  press ----- press ----- False ----- NOUN
#  conference ----- conference ----- False ----- NOUN
#  in ----- in ----- True ----- ADP
#  lebanon ----- lebanon ----- False ----- PROPN
#  ahead ----- ahead ----- False ----- ADV
#  of ----- of ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  cnn ----- cnn ----- False ----- PROPN
#  interview ----- interview ----- False ----- NOUN
#  last ----- last ----- True ----- ADJ
#  wednesday ----- wednesday ----- False ----- PROPN
#  , ----- , ----- False ----- PUNCT
#  ghosn ----- ghosn ----- False ----- PROPN
#  's ----- 's ----- True ----- PART
#  first ----- first ----- True ----- ADJ
#  public ----- public ----- False ----- ADJ
#  appearance ----- appearance ----- False ----- NOUN
#  since ----- since ----- True ----- SCONJ
#  fleeing ----- flee ----- False ----- VERB
#  japan ----- japan ----- False ----- PROPN
#  , ----- , ----- False ----- PUNCT
#  ghosn ----- ghosn ----- False ----- PROPN
#  said ----- say ----- False ----- VERB
#  he ----- -PRON- ----- True ----- PRON
#  decided ----- decide ----- False ----- VERB
#  to ----- to ----- True ----- PART
#  leave ----- leave ----- False ----- VERB
#  the ----- the ----- True ----- DET
#  country ----- country ----- False ----- NOUN
#  because ----- because ----- True ----- SCONJ
#  he ----- -PRON- ----- True ----- PRON
#  believed ----- believe ----- False ----- VERB
#  he ----- -PRON- ----- True ----- PRON
#  would ----- would ----- True ----- VERB
#  not ----- not ----- True ----- PART
#  receive ----- receive ----- False ----- VERB
#  a ----- a ----- True ----- DET
#  fair ----- fair ----- False ----- ADJ
#  trial ----- trial ----- False ----- NOUN
#  , ----- , ----- False ----- PUNCT
#  a ----- a ----- True ----- DET
#  claim ----- claim ----- False ----- NOUN
#  japanese ----- japanese ----- False ----- ADJ
#  authorities ----- authority ----- False ----- NOUN
#  have ----- have ----- True ----- AUX
#  disputed ----- dispute ----- False ----- VERB
#  . ----- . ----- False ----- PUNCT
#  brands ----- brand ----- False ----- NOUN
#  sometimes ----- sometimes ----- True ----- ADV
#  capitalize ----- capitalize ----- False ----- VERB
#  on ----- on ----- True ----- ADP
#  their ----- -PRON- ----- True ----- DET
#  tangential ----- tangential ----- False ----- ADJ
#  relationship ----- relationship ----- False ----- NOUN
#  to ----- to ----- True ----- ADP
#  big ----- big ----- False ----- ADJ
#  news ----- news ----- False ----- NOUN
#  in ----- in ----- True ----- ADP
#  order ----- order ----- False ----- NOUN
#  to ----- to ----- True ----- PART
#  attract ----- attract ----- False ----- VERB
#  attention ----- attention ----- False ----- NOUN
#  on ----- on ----- True ----- ADP
#  social ----- social ----- False ----- ADJ
#  media ----- medium ----- False ----- NOUN
#  . ----- . ----- False ----- PUNCT
#  yamaha ----- yamaha ----- False ----- PROPN
#  is ----- be ----- True ----- AUX
#  one ----- one ----- True ----- NUM
#  of ----- of ----- True ----- ADP
#  japan ----- japan ----- False ----- PROPN
#  's ----- 's ----- True ----- PART
#  best ----- well ----- False ----- ADV
#  known ----- know ----- False ----- VERB
#  brands ----- brand ----- False ----- NOUN
#  and ----- and ----- True ----- CCONJ
#  ghosn ----- ghosn ----- False ----- PROPN
#  was ----- be ----- True ----- AUX
#  one ----- one ----- True ----- NUM
#  of ----- of ----- True ----- ADP
#  japan ----- japan ----- False ----- PROPN
#  's ----- 's ----- True ----- PART
#  top ----- top ----- True ----- ADJ
#  executives ----- executive ----- False ----- NOUN
#  before ----- before ----- True ----- ADP
#  being ----- be ----- True ----- AUX
#  ousted ----- oust ----- False ----- VERB
#  from ----- from ----- True ----- ADP
#  nissan ----- nissan ----- False ----- PROPN
#  — ----- — ----- False ----- PUNCT
#  a ----- a ----- True ----- DET
#  match ----- match ----- False ----- NOUN
#  made ----- make ----- True ----- VERB
#  in ----- in ----- True ----- ADP
#  social ----- social ----- False ----- ADJ
#  media ----- medium ----- False ----- NOUN
#  heaven ----- heaven ----- False ----- PROPN
#  . ----- . ----- False ----- PUNCT
#  not ----- not ----- True ----- PART
#  surprisingly ----- surprisingly ----- False ----- ADV
#  , ----- , ----- False ----- PUNCT
#  yamaha ----- yamaha ----- False ----- PROPN
#  's ----- 's ----- True ----- PART
#  post ----- post ----- False ----- NOUN
#  went ----- go ----- False ----- VERB
#  viral ----- viral ----- False ----- ADJ
#  on ----- on ----- True ----- ADP
#  twitter ----- twitter ----- False ----- PROPN
#  over ----- over ----- True ----- ADP
#  the ----- the ----- True ----- DET
#  weekend ----- weekend ----- False ----- NOUN
#  . ----- . ----- False ----- PUNCT

# %% [markdown]
# ### Extract keywords (filter out keywords)

# %%
# init blank keyword list 
keyword = []

for token in doc:
    # check if current token is a stop word or punctuation, if yes then skip
    if token.text in nlp.Defaults.stop_words or token.text in punctuation:
        continue

    # if token text is Noun, Verb, Adjective or Propernoun, save to keywords list
    elif token.pos_ in ['NOUN','VERB','ADJ','PROPN']:
       keyword.append(token.text)

# check populated keyword list
keyword
# Out:
# ['yamaha',
#  'reminding',
#  'people',
#  'musical',
#  'equipment',
#  'cases',
#  'musical',
#  'equipment',
#  'people',
#  'weeks',
#  'fugitive',
#  'auto',
#  'titan',
#  'carlos',
#  'ghosn',
#  'smuggled',
#  'japan',
#  'tweet',
#  'weekend',
#  'japanese',
#  'musical',
#  'equipment',
#  'company',
#  'said',
#  'naming',
#  'names',
#  'noted',
#  'recent',
#  'stories',
#  'people',
#  'getting',
#  'musical',
#  'equipment',
#  'cases',
#  'yamaha',
#  'yamcy',
#  'warned',
#  'people',
#  'let',
#  'cases',
#  'avoid',
#  'unfortunate',
#  'accidents',
#  'multiple',
#  'media',
#  'outlets',
#  'reported',
#  'ghosn',
#  'managed',
#  'sneak',
#  'japanese',
#  'airport',
#  'private',
#  'jet',
#  'whisked',
#  'country',
#  'hiding',
#  'large',
#  'black',
#  'music',
#  'equipment',
#  'case',
#  'breathing',
#  'holes',
#  'drilled',
#  'cnn',
#  'business',
#  'confirmed',
#  'details',
#  'escape',
#  'nissan',
#  'nsanf',
#  'ceo',
#  'bail',
#  'awaiting',
#  'trial',
#  'japan',
#  'charges',
#  'financial',
#  'wrongdoing',
#  'making',
#  'stunning',
#  'escape',
#  'lebanon',
#  'end',
#  'december',
#  'ghosn',
#  'referred',
#  'departure',
#  'effort',
#  'escape',
#  'injustice',
#  'interview',
#  'cnn',
#  'richard',
#  'quest',
#  'week',
#  'ghosn',
#  'comment',
#  'nature',
#  'escape',
#  'saying',
#  'want',
#  'endanger',
#  'people',
#  'aided',
#  'operation',
#  'ghosn',
#  'respond',
#  'question',
#  'felt',
#  'ride',
#  'airport',
#  'packing',
#  'case',
#  'declining',
#  'comment',
#  'adding',
#  'freedom',
#  'way',
#  'happens',
#  'sweet',
#  'press',
#  'conference',
#  'lebanon',
#  'cnn',
#  'interview',
#  'wednesday',
#  'ghosn',
#  'public',
#  'appearance',
#  'fleeing',
#  'japan',
#  'ghosn',
#  'said',
#  'decided',
#  'leave',
#  'country',
#  'believed',
#  'receive',
#  'fair',
#  'trial',
#  'claim',
#  'japanese',
#  'authorities',
#  'disputed',
#  'brands',
#  'capitalize',
#  'tangential',
#  'relationship',
#  'big',
#  'news',
#  'order',
#  'attract',
#  'attention',
#  'social',
#  'media',
#  'yamaha',
#  'japan',
#  'known',
#  'brands',
#  'ghosn',
#  'japan',
#  'executives',
#  'ousted',
#  'nissan',
#  'match',
#  'social',
#  'media',
#  'heaven',
#  'yamaha',
#  'post',
#  'went',
#  'viral',
#  'twitter',
#  'weekend']

# %% [markdown]
# ### Normalize weightage of keywords
#
# ##### Get frequency of each word
#
# - `Counter` will convert the list into a dictionary with their respective frequency values

# %%
# get frequency of each word
freq_of_keywords = Counter(keyword)

# pretty print frequency of words 
pprint.pprint(freq_of_keywords)
# Out:
# Counter({'ghosn': 8,
#          'people': 5,
#          'equipment': 5,
#          'japan': 5,
#          'yamaha': 4,
#          'musical': 4,
#          'escape': 4,
#          'cases': 3,
#          'japanese': 3,
#          'media': 3,
#          'cnn': 3,
#          'weekend': 2,
#          'said': 2,
#          'airport': 2,
#          'country': 2,
#          'case': 2,
#          'nissan': 2,
#          'trial': 2,
#          'lebanon': 2,
#          'interview': 2,
#          'comment': 2,
#          'brands': 2,
#          'social': 2,
#          'reminding': 1,
#          'weeks': 1,
#          'fugitive': 1,
#          'auto': 1,
#          'titan': 1,
#          'carlos': 1,
#          'smuggled': 1,
#          'tweet': 1,
#          'company': 1,
#          'naming': 1,
#          'names': 1,
#          'noted': 1,
#          'recent': 1,
#          'stories': 1,
#          'getting': 1,
#          'yamcy': 1,
#          'warned': 1,
#          'let': 1,
#          'avoid': 1,
#          'unfortunate': 1,
#          'accidents': 1,
#          'multiple': 1,
#          'outlets': 1,
#          'reported': 1,
#          'managed': 1,
#          'sneak': 1,
#          'private': 1,
#          'jet': 1,
#          'whisked': 1,
#          'hiding': 1,
#          'large': 1,
#          'black': 1,
#          'music': 1,
#          'breathing': 1,
#          'holes': 1,
#          'drilled': 1,
#          'business': 1,
#          'confirmed': 1,
#          'details': 1,
#          'nsanf': 1,
#          'ceo': 1,
#          'bail': 1,
#          'awaiting': 1,
#          'charges': 1,
#          'financial': 1,
#          'wrongdoing': 1,
#          'making': 1,
#          'stunning': 1,
#          'end': 1,
#          'december': 1,
#          'referred': 1,
#          'departure': 1,
#          'effort': 1,
#          'injustice': 1,
#          'richard': 1,
#          'quest': 1,
#          'week': 1,
#          'nature': 1,
#          'saying': 1,
#          'want': 1,
#          'endanger': 1,
#          'aided': 1,
#          'operation': 1,
#          'respond': 1,
#          'question': 1,
#          'felt': 1,
#          'ride': 1,
#          'packing': 1,
#          'declining': 1,
#          'adding': 1,
#          'freedom': 1,
#          'way': 1,
#          'happens': 1,
#          'sweet': 1,
#          'press': 1,
#          'conference': 1,
#          'wednesday': 1,
#          'public': 1,
#          'appearance': 1,
#          'fleeing': 1,
#          'decided': 1,
#          'leave': 1,
#          'believed': 1,
#          'receive': 1,
#          'fair': 1,
#          'claim': 1,
#          'authorities': 1,
#          'disputed': 1,
#          'capitalize': 1,
#          'tangential': 1,
#          'relationship': 1,
#          'big': 1,
#          'news': 1,
#          'order': 1,
#          'attract': 1,
#          'attention': 1,
#          'known': 1,
#          'executives': 1,
#          'ousted': 1,
#          'match': 1,
#          'heaven': 1,
#          'post': 1,
#          'went': 1,
#          'viral': 1,
#          'twitter': 1})

# %% [markdown]
# ##### Sort by frequency - most common to least common

# %%
# get the most frequent keyword
sort_occurence = freq_of_keywords.most_common()
pprint.pprint(sort_occurence)
# Out:
# [('ghosn', 8),
#  ('people', 5),
#  ('equipment', 5),
#  ('japan', 5),
#  ('yamaha', 4),
#  ('musical', 4),
#  ('escape', 4),
#  ('cases', 3),
#  ('japanese', 3),
#  ('media', 3),
#  ('cnn', 3),
#  ('weekend', 2),
#  ('said', 2),
#  ('airport', 2),
#  ('country', 2),
#  ('case', 2),
#  ('nissan', 2),
#  ('trial', 2),
#  ('lebanon', 2),
#  ('interview', 2),
#  ('comment', 2),
#  ('brands', 2),
#  ('social', 2),
#  ('reminding', 1),
#  ('weeks', 1),
#  ('fugitive', 1),
#  ('auto', 1),
#  ('titan', 1),
#  ('carlos', 1),
#  ('smuggled', 1),
#  ('tweet', 1),
#  ('company', 1),
#  ('naming', 1),
#  ('names', 1),
#  ('noted', 1),
#  ('recent', 1),
#  ('stories', 1),
#  ('getting', 1),
#  ('yamcy', 1),
#  ('warned', 1),
#  ('let', 1),
#  ('avoid', 1),
#  ('unfortunate', 1),
#  ('accidents', 1),
#  ('multiple', 1),
#  ('outlets', 1),
#  ('reported', 1),
#  ('managed', 1),
#  ('sneak', 1),
#  ('private', 1),
#  ('jet', 1),
#  ('whisked', 1),
#  ('hiding', 1),
#  ('large', 1),
#  ('black', 1),
#  ('music', 1),
#  ('breathing', 1),
#  ('holes', 1),
#  ('drilled', 1),
#  ('business', 1),
#  ('confirmed', 1),
#  ('details', 1),
#  ('nsanf', 1),
#  ('ceo', 1),
#  ('bail', 1),
#  ('awaiting', 1),
#  ('charges', 1),
#  ('financial', 1),
#  ('wrongdoing', 1),
#  ('making', 1),
#  ('stunning', 1),
#  ('end', 1),
#  ('december', 1),
#  ('referred', 1),
#  ('departure', 1),
#  ('effort', 1),
#  ('injustice', 1),
#  ('richard', 1),
#  ('quest', 1),
#  ('week', 1),
#  ('nature', 1),
#  ('saying', 1),
#  ('want', 1),
#  ('endanger', 1),
#  ('aided', 1),
#  ('operation', 1),
#  ('respond', 1),
#  ('question', 1),
#  ('felt', 1),
#  ('ride', 1),
#  ('packing', 1),
#  ('declining', 1),
#  ('adding', 1),
#  ('freedom', 1),
#  ('way', 1),
#  ('happens', 1),
#  ('sweet', 1),
#  ('press', 1),
#  ('conference', 1),
#  ('wednesday', 1),
#  ('public', 1),
#  ('appearance', 1),
#  ('fleeing', 1),
#  ('decided', 1),
#  ('leave', 1),
#  ('believed', 1),
#  ('receive', 1),
#  ('fair', 1),
#  ('claim', 1),
#  ('authorities', 1),
#  ('disputed', 1),
#  ('capitalize', 1),
#  ('tangential', 1),
#  ('relationship', 1),
#  ('big', 1),
#  ('news', 1),
#  ('order', 1),
#  ('attract', 1),
#  ('attention', 1),
#  ('known', 1),
#  ('executives', 1),
#  ('ousted', 1),
#  ('match', 1),
#  ('heaven', 1),
#  ('post', 1),
#  ('went', 1),
#  ('viral', 1),
#  ('twitter', 1)]

# %% [markdown]
# ##### Get the most common word

# %%
print(sort_occurence[0])
# Out:
# ('ghosn', 8)

# %% [markdown]
# ##### Get frequency of most common word

# %%
max_frequency = sort_occurence[0][1]
print(max_frequency)
# Out:
# 8

# %% [markdown]
# ##### Normalize frequency of each keyword with the max frequency value

# %%
for word in freq_of_keywords:
    freq_of_words[word] = freq_of_keywords[word]/max_frequency

print('Normalized TF:'+'-'*50,'\n')
pprint.pprint(freq_of_words)
# Out:
# Normalized TF:--------------------------------------------------
#
# Counter({'ghosn': 1.0,
#          'people': 0.625,
#          'equipment': 0.625,
#          'japan': 0.625,
#          'yamaha': 0.5,
#          'musical': 0.5,
#          'escape': 0.5,
#          'cases': 0.375,
#          'japanese': 0.375,
#          'media': 0.375,
#          'cnn': 0.375,
#          'weekend': 0.25,
#          'said': 0.25,
#          'airport': 0.25,
#          'country': 0.25,
#          'case': 0.25,
#          'nissan': 0.25,
#          'trial': 0.25,
#          'lebanon': 0.25,
#          'interview': 0.25,
#          'comment': 0.25,
#          'brands': 0.25,
#          'social': 0.25,
#          'reminding': 0.125,
#          'weeks': 0.125,
#          'fugitive': 0.125,
#          'auto': 0.125,
#          'titan': 0.125,
#          'carlos': 0.125,
#          'smuggled': 0.125,
#          'tweet': 0.125,
#          'company': 0.125,
#          'naming': 0.125,
#          'names': 0.125,
#          'noted': 0.125,
#          'recent': 0.125,
#          'stories': 0.125,
#          'getting': 0.125,
#          'yamcy': 0.125,
#          'warned': 0.125,
#          'let': 0.125,
#          'avoid': 0.125,
#          'unfortunate': 0.125,
#          'accidents': 0.125,
#          'multiple': 0.125,
#          'outlets': 0.125,
#          'reported': 0.125,
#          'managed': 0.125,
#          'sneak': 0.125,
#          'private': 0.125,
#          'jet': 0.125,
#          'whisked': 0.125,
#          'hiding': 0.125,
#          'large': 0.125,
#          'black': 0.125,
#          'music': 0.125,
#          'breathing': 0.125,
#          'holes': 0.125,
#          'drilled': 0.125,
#          'business': 0.125,
#          'confirmed': 0.125,
#          'details': 0.125,
#          'nsanf': 0.125,
#          'ceo': 0.125,
#          'bail': 0.125,
#          'awaiting': 0.125,
#          'charges': 0.125,
#          'financial': 0.125,
#          'wrongdoing': 0.125,
#          'making': 0.125,
#          'stunning': 0.125,
#          'end': 0.125,
#          'december': 0.125,
#          'referred': 0.125,
#          'departure': 0.125,
#          'effort': 0.125,
#          'injustice': 0.125,
#          'richard': 0.125,
#          'quest': 0.125,
#          'week': 0.125,
#          'nature': 0.125,
#          'saying': 0.125,
#          'want': 0.125,
#          'endanger': 0.125,
#          'aided': 0.125,
#          'operation': 0.125,
#          'respond': 0.125,
#          'question': 0.125,
#          'felt': 0.125,
#          'ride': 0.125,
#          'packing': 0.125,
#          'declining': 0.125,
#          'adding': 0.125,
#          'freedom': 0.125,
#          'way': 0.125,
#          'happens': 0.125,
#          'sweet': 0.125,
#          'press': 0.125,
#          'conference': 0.125,
#          'wednesday': 0.125,
#          'public': 0.125,
#          'appearance': 0.125,
#          'fleeing': 0.125,
#          'decided': 0.125,
#          'leave': 0.125,
#          'believed': 0.125,
#          'receive': 0.125,
#          'fair': 0.125,
#          'claim': 0.125,
#          'authorities': 0.125,
#          'disputed': 0.125,
#          'capitalize': 0.125,
#          'tangential': 0.125,
#          'relationship': 0.125,
#          'big': 0.125,
#          'news': 0.125,
#          'order': 0.125,
#          'attract': 0.125,
#          'attention': 0.125,
#          'known': 0.125,
#          'executives': 0.125,
#          'ousted': 0.125,
#          'match': 0.125,
#          'heaven': 0.125,
#          'post': 0.125,
#          'went': 0.125,
#          'viral': 0.125,
#          'twitter': 0.125})

# %% [markdown]
# ### Sentence Importance Computation

# %% [markdown]
# ##### Extract all sentences

# %%
for sentence in doc.sents:
    print('-'*150)
    pprint.pprint(sentence)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# yamaha is reminding people that musical equipment cases are for musical equipment — not people — two weeks after fugitive auto titan carlos ghosn reportedly was smuggled out of japan in one.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# in a tweet over the weekend, the japanese musical equipment company said it was not naming any names, but noted there had been many recent stories about people getting into musical equipment cases.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# yamaha (yamcy) warned people not to get into, or let others get into, its cases to avoid "unfortunate accidents.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# " multiple media outlets have reported that ghosn managed to sneak through a japanese airport to a private jet that whisked him out of the country by hiding in a large, black music equipment case with breathing holes drilled in the bottom.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# cnn business has not independently confirmed those details of his escape.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# the former nissan (nsanf) ceo had been out on bail awaiting trial in japan on charges of financial wrongdoing before making his stunning escape to lebanon at the end of december.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ghosn has referred to his departure as an effort to "escape injustice."
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# in an interview with cnn's richard quest last week, ghosn did not comment on the nature of his escape, saying he didn't want to endanger any of the people who aided in the operation.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# ghosn did, however, respond to a question about what it felt like to ride through the airport in a packing case by first declining to comment but then adding: "freedom, no matter the way it happens, is always sweet."
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# in a press conference in lebanon ahead of the cnn interview last wednesday, ghosn's first public appearance since fleeing japan, ghosn said he decided to leave the country because he believed he would not receive a fair trial, a claim japanese authorities have disputed.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# brands sometimes capitalize on their tangential relationship to big news in order to attract attention on social media.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# yamaha is one of japan's best known brands and ghosn was one of japan's top executives before being ousted from nissan — a match made in social media heaven.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# not surprisingly, yamaha's post went viral on twitter over the weekend.

# %%
# access each word in each sentence
for sentence in doc.sents:
    print('='*150)
    for word in sentence:
        print('---'*10)
        print(word, ', type:' ,type(word))
# Out:
# ======================================================================================================================================================
# ------------------------------
# yamaha , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# is , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# reminding , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# people , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# that , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# musical , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# equipment , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# cases , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# are , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# for , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# musical , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# equipment , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# — , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# not , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# people , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# — , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# two , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# weeks , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# after , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# fugitive , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# auto , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# titan , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# carlos , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ghosn , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# reportedly , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# was , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# smuggled , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# out , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# japan , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# one , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# a , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# tweet , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# over , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# weekend , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# japanese , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# musical , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# equipment , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# company , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# said , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# it , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# was , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# not , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# naming , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# any , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# names , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# but , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# noted , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# there , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# had , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# been , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# many , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# recent , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# stories , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# about , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# people , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# getting , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# into , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# musical , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# equipment , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# cases , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# yamaha , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ( , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# yamcy , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ) , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# warned , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# people , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# not , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# get , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# into , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# or , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# let , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# others , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# get , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# into , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# its , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# cases , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# avoid , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# " , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# unfortunate , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# accidents , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# " , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# multiple , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# media , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# outlets , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# have , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# reported , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# that , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ghosn , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# managed , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# sneak , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# through , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# a , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# japanese , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# airport , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# a , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# private , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# jet , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# that , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# whisked , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# him , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# out , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# country , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# by , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# hiding , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# a , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# large , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# black , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# music , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# equipment , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# case , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# with , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# breathing , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# holes , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# drilled , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# bottom , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# cnn , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# business , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# has , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# not , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# independently , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# confirmed , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# those , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# details , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# his , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# escape , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# former , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# nissan , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ( , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# nsanf , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ) , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ceo , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# had , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# been , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# out , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# on , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# bail , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# awaiting , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# trial , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# japan , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# on , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# charges , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# financial , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# wrongdoing , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# before , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# making , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# his , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# stunning , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# escape , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# lebanon , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# at , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# end , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# december , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# ghosn , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# has , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# referred , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# his , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# departure , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# as , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# an , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# effort , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# " , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# escape , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# injustice , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# " , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# an , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# interview , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# with , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# cnn , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# 's , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# richard , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# quest , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# last , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# week , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ghosn , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# did , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# not , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# comment , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# on , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# nature , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# his , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# escape , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# saying , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# he , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# did , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# n't , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# want , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# endanger , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# any , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# people , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# who , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# aided , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# operation , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# ghosn , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# did , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# however , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# respond , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# a , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# question , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# about , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# what , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# it , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# felt , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# like , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ride , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# through , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# airport , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# a , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# packing , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# case , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# by , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# first , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# declining , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# comment , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# but , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# then , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# adding , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# : , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# " , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# freedom , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# no , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# matter , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# way , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# it , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# happens , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# is , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# always , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# sweet , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# " , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# a , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# press , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# conference , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# lebanon , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ahead , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# cnn , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# interview , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# last , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# wednesday , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ghosn , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# 's , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# first , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# public , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# appearance , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# since , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# fleeing , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# japan , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ghosn , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# said , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# he , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# decided , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# leave , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# country , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# because , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# he , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# believed , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# he , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# would , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# not , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# receive , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# a , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# fair , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# trial , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# a , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# claim , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# japanese , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# authorities , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# have , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# disputed , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# brands , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# sometimes , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# capitalize , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# on , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# their , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# tangential , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# relationship , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# big , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# news , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# order , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# to , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# attract , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# attention , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# on , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# social , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# media , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# yamaha , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# is , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# one , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# japan , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# 's , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# best , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# known , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# brands , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# and , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ghosn , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# was , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# one , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# of , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# japan , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# 's , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# top , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# executives , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# before , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# being , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# ousted , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# from , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# nissan , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# — , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# a , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# match , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# made , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# in , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# social , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# media , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# heaven , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>
# ======================================================================================================================================================
# ------------------------------
# not , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# surprisingly , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# , , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# yamaha , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# 's , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# post , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# went , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# viral , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# on , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# twitter , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# over , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# the , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# weekend , type: <class 'spacy.tokens.token.Token'>
# ------------------------------
# . , type: <class 'spacy.tokens.token.Token'>

# %% [markdown]
# ##### Exploratory Sentence-Word Analysis

# %%
# access each word in each sentence 
# check if word is in list of keywords
for sentence in doc.sents:
    print('='*150)
    for word in sentence:
        print('---'*15)
        print(word.text)
        print('keyword? = ', word.text in freq_of_keywords.keys()) # check if word text is a keyword
        print('stop-word? = ', word.is_stop ) # check if word-token is a stop word
# Out:
# ======================================================================================================================================================
# ---------------------------------------------
# yamaha
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# is
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# reminding
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# people
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# that
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# musical
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# equipment
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# cases
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# are
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# for
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# musical
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# equipment
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# —
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# not
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# people
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# —
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# two
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# weeks
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# after
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# fugitive
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# auto
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# titan
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# carlos
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ghosn
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# reportedly
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# was
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# smuggled
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# out
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# japan
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# one
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# a
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# tweet
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# over
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# weekend
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# japanese
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# musical
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# equipment
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# company
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# said
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# it
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# was
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# not
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# naming
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# any
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# names
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# but
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# noted
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# there
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# had
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# been
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# many
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# recent
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# stories
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# about
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# people
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# getting
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# into
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# musical
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# equipment
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# cases
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# yamaha
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# (
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# yamcy
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# )
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# warned
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# people
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# not
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# get
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# into
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# or
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# let
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# others
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# get
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# into
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# its
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# cases
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# avoid
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# "
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# unfortunate
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# accidents
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# "
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# multiple
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# media
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# outlets
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# have
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# reported
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# that
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# ghosn
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# managed
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# sneak
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# through
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# a
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# japanese
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# airport
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# a
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# private
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# jet
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# that
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# whisked
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# him
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# out
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# country
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# by
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# hiding
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# a
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# large
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# black
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# music
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# equipment
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# case
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# with
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# breathing
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# holes
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# drilled
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# bottom
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# cnn
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# business
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# has
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# not
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# independently
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# confirmed
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# those
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# details
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# his
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# escape
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# former
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# nissan
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# (
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# nsanf
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# )
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# ceo
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# had
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# been
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# out
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# on
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# bail
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# awaiting
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# trial
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# japan
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# on
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# charges
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# financial
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# wrongdoing
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# before
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# making
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# his
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# stunning
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# escape
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# lebanon
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# at
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# end
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# december
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# ghosn
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# has
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# referred
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# his
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# departure
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# as
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# an
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# effort
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# "
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# escape
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# injustice
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# "
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# an
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# interview
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# with
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# cnn
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# 's
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# richard
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# quest
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# last
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# week
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# ghosn
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# did
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# not
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# comment
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# on
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# nature
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# his
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# escape
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# saying
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# he
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# did
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# n't
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# want
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# endanger
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# any
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# people
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# who
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# aided
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# operation
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# ghosn
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# did
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# however
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# respond
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# a
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# question
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# about
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# what
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# it
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# felt
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# like
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# ride
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# through
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# airport
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# a
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# packing
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# case
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# by
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# first
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# declining
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# comment
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# but
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# then
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# adding
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# :
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# "
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# freedom
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# no
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# matter
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# way
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# it
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# happens
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# is
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# always
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# sweet
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# "
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# a
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# press
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# conference
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# lebanon
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ahead
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# cnn
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# interview
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# last
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# wednesday
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# ghosn
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# 's
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# first
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# public
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# appearance
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# since
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# fleeing
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# japan
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# ghosn
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# said
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# he
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# decided
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# leave
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# country
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# because
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# he
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# believed
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# he
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# would
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# not
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# receive
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# a
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# fair
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# trial
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# a
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# claim
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# japanese
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# authorities
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# have
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# disputed
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# brands
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# sometimes
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# capitalize
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# on
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# their
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# tangential
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# relationship
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# big
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# news
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# order
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# to
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# attract
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# attention
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# on
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# social
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# media
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# yamaha
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# is
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# one
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# japan
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# 's
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# best
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# known
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# brands
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# and
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# ghosn
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# was
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# one
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# of
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# japan
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# 's
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# top
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# executives
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# before
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# being
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# ousted
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# from
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# nissan
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# —
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# a
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# match
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# made
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# in
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# social
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# media
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# heaven
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False
# ======================================================================================================================================================
# ---------------------------------------------
# not
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# surprisingly
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# ,
# keyword? =  False
# stop-word? =  False
# ---------------------------------------------
# yamaha
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# 's
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# post
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# went
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# viral
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# on
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# twitter
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# over
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# the
# keyword? =  False
# stop-word? =  True
# ---------------------------------------------
# weekend
# keyword? =  True
# stop-word? =  False
# ---------------------------------------------
# .
# keyword? =  False
# stop-word? =  False

# %% [markdown]
# ##### Calculate the importance of the sentences
#
# - identify occurence of important keywords in each sentence
#
# - then, sum up the value to weight each sentence

# %%
# initialize dictionary to accumulate strength for each sentence
sentence_strength = {}

# %% [markdown]
# - for a given sentence
#
#     - each time a word is found in the `freq_of_keywords` dictionary
#
#     - add the frequency of the word to the sentence strength

# %%
# loop over each sentence in document
for sentence in doc.sents:

    # loop over each word in current sentence 
    for word in sentence: 

        # check if current word is in important keyword list
        if word.text in freq_of_keywords.keys():

            # check if current sentence is present in sentence_strength dictionary 
            if sentence in sentence_strength.keys():

                # increase weight of sentence by normalized frequency of the current word
                sentence_strength[sentence] += freq_of_keywords[word.text]

            # if sentence is not in the sentence_strength dictionary
            else:
                
                # create key entry for current sentence and set the value to current word's normalized frequecy
                sentence_strength[sentence] = freq_of_keywords[word.text]

pprint.pprint(sentence_strength)
# Out:
# {yamaha is reminding people that musical equipment cases are for musical equipment — not people — two weeks after fugitive auto titan carlos ghosn reportedly was smuggled out of japan in one.: 55,
#  in a tweet over the weekend, the japanese musical equipment company said it was not naming any names, but noted there had been many recent stories about people getting into musical equipment cases.: 41,
#  yamaha (yamcy) warned people not to get into, or let others get into, its cases to avoid "unfortunate accidents.: 18,
#  " multiple media outlets have reported that ghosn managed to sneak through a japanese airport to a private jet that whisked him out of the country by hiding in a large, black music equipment case with breathing holes drilled in the bottom.: 40,
#  cnn business has not independently confirmed those details of his escape.: 10,
#  the former nissan (nsanf) ceo had been out on bail awaiting trial in japan on charges of financial wrongdoing before making his stunning escape to lebanon at the end of december.: 26,
#  ghosn has referred to his departure as an effort to "escape injustice.": 16,
#  in an interview with cnn's richard quest last week, ghosn did not comment on the nature of his escape, saying he didn't want to endanger any of the people who aided in the operation.: 33,
#  ghosn did, however, respond to a question about what it felt like to ride through the airport in a packing case by first declining to comment but then adding: "freedom, no matter the way it happens, is always sweet.": 25,
#  in a press conference in lebanon ahead of the cnn interview last wednesday, ghosn's first public appearance since fleeing japan, ghosn said he decided to leave the country because he believed he would not receive a fair trial, a claim japanese authorities have disputed.: 51,
#  brands sometimes capitalize on their tangential relationship to big news in order to attract attention on social media.: 15,
#  yamaha is one of japan's best known brands and ghosn was one of japan's top executives before being ousted from nissan — a match made in social media heaven.: 36,
#  not surprisingly, yamaha's post went viral on twitter over the weekend.: 10}

# %% [markdown]
# ### Sort the sentences by their strengths (importance)

# %%
sorted_sentence_strengths = sorted(sentence_strength.items(), key = lambda key_value: key_value[1], reverse=True)
pprint.pprint(sorted_sentence_strengths)
# Out:
# [(yamaha is reminding people that musical equipment cases are for musical equipment — not people — two weeks after fugitive auto titan carlos ghosn reportedly was smuggled out of japan in one.,
#   55),
#  (in a press conference in lebanon ahead of the cnn interview last wednesday, ghosn's first public appearance since fleeing japan, ghosn said he decided to leave the country because he believed he would not receive a fair trial, a claim japanese authorities have disputed.,
#   51),
#  (in a tweet over the weekend, the japanese musical equipment company said it was not naming any names, but noted there had been many recent stories about people getting into musical equipment cases.,
#   41),
#  (" multiple media outlets have reported that ghosn managed to sneak through a japanese airport to a private jet that whisked him out of the country by hiding in a large, black music equipment case with breathing holes drilled in the bottom.,
#   40),
#  (yamaha is one of japan's best known brands and ghosn was one of japan's top executives before being ousted from nissan — a match made in social media heaven.,
#   36),
#  (in an interview with cnn's richard quest last week, ghosn did not comment on the nature of his escape, saying he didn't want to endanger any of the people who aided in the operation.,
#   33),
#  (the former nissan (nsanf) ceo had been out on bail awaiting trial in japan on charges of financial wrongdoing before making his stunning escape to lebanon at the end of december.,
#   26),
#  (ghosn did, however, respond to a question about what it felt like to ride through the airport in a packing case by first declining to comment but then adding: "freedom, no matter the way it happens, is always sweet.",
#   25),
#  (yamaha (yamcy) warned people not to get into, or let others get into, its cases to avoid "unfortunate accidents.,
#   18),
#  (ghosn has referred to his departure as an effort to "escape injustice.", 16),
#  (brands sometimes capitalize on their tangential relationship to big news in order to attract attention on social media.,
#   15),
#  (cnn business has not independently confirmed those details of his escape.,
#   10),
#  (not surprisingly, yamaha's post went viral on twitter over the weekend., 10)]

# %% [markdown]
# ### Set summary sentence limit

# %%
num_summary_sentences = 3

# %% [markdown]
# ##### Extract the first `num_summary_sentences` from the `soreted_sentence_strength` list

# %%
if num_summary_sentences <= len(sorted_sentence_strengths):
    summary_sentence_set = sorted_sentence_strengths[:num_summary_sentences]
else: 
    print('Number of sentences required in summary is more than sentences in original text!')

pprint.pprint(summary_sentence_set)
# Out:
# [(yamaha is reminding people that musical equipment cases are for musical equipment — not people — two weeks after fugitive auto titan carlos ghosn reportedly was smuggled out of japan in one.,
#   55),
#  (in a press conference in lebanon ahead of the cnn interview last wednesday, ghosn's first public appearance since fleeing japan, ghosn said he decided to leave the country because he believed he would not receive a fair trial, a claim japanese authorities have disputed.,
#   51),
#  (in a tweet over the weekend, the japanese musical equipment company said it was not naming any names, but noted there had been many recent stories about people getting into musical equipment cases.,
#   41)]

# %% [markdown]
# ### Generate final summary
#
# - by cleaning up the extracted sentence list

# %%
summary = ' '.join([ item[0].text.capitalize() for item in summary_sentence_set ])
print(summary)
# Out:
# Yamaha is reminding people that musical equipment cases are for musical equipment — not people — two weeks after fugitive auto titan carlos ghosn reportedly was smuggled out of japan in one. In a press conference in lebanon ahead of the cnn interview last wednesday, ghosn's first public appearance since fleeing japan, ghosn said he decided to leave the country because he believed he would not receive a fair trial, a claim japanese authorities have disputed. In a tweet over the weekend, the japanese musical equipment company said it was not naming any names, but noted there had been many recent stories about people getting into musical equipment cases.
